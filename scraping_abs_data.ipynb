# %%
import os
import pandas as pd
import numpy as np
import re
import selenium
from selenium import webdriver

import random
import time

from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
# Get suburb name and state from aus_suburb table.
def convert_to_acronym(state_var):
    if state_var == 'New South Wales':
        state_var = 'NSW'
    elif state_var == 'Victoria':
        state_var = 'Vic'
    elif state_var == 'Australian Capital Territory':
        state_var = 'ACT'
    elif state_var == 'Queensland':
        state_var = 'Qld'
    elif state_var == 'South Australia':
        state_var = 'SA'
    elif state_var == 'Northern Territory':
        state_var = 'NT'
    elif state_var == 'Western Australia':
        state_var = 'WA'
    elif state_var == 'Tasmania':
        state_var = 'Tas'
    return state_var

# %%
def find_abs_quick_stat_webpage(suburb, state):
    # Select the id box
    id_box = driver.find_element_by_class_name('gwt-SearchWidget-SuggestBox-Fade')

    # Send id information
    id_box.send_keys(suburb)

    # Time delay (minimum of 0.2 sec required)
    num = random.uniform(1.0,2.0)
    print(num)
    time.sleep(num)

    # Get pop-up table
    popup_table_id = driver.find_element_by_class_name('suggestPopupMiddleCenter')

    # Get suburb index from popup table
    rows = popup_table_id.find_elements_by_tag_name("tr")

    counter = -1
    var_check = 0
    for row in rows:
        counter = counter + 1
        popup_text = row.text
        if 'State Suburb (SSC)' in popup_text:
            if state in popup_text:
                popup_text = popup_text.replace('State Suburb (SSC)', '')
                popup_text = popup_text.split(',')[0].split('(')[0]
                popup_text = popup_text.strip()
                if suburb == popup_text:
                    var_check = 1
                    break
                    
    # If State Suburb doesn't exist for suburb in the given popup list,
    # then check for State Electoral Division.
    
    if var_check == 0:
        counter = -1
        for row in rows:
            counter = counter + 1
            popup_text = row.text
            if 'State Electoral Division (SED)' in popup_text:
                if state in popup_text:
                    popup_text = popup_text.replace('State Electoral Division (SED)', '')
                    popup_text = re.sub('[\(\[].*?[\)\]]', '', popup_text)
                    popup_text = popup_text.split(',')[0].split('(')[0]
                    popup_text = popup_text.strip()
                    if suburb == popup_text:
                        print(popup_text)
                        break
                
    # Get Suburb gwt-uid from popup table 
    IDs = popup_table_id.find_elements_by_tag_name('td')
    suburb_uid = IDs[counter].get_attribute('id')

    # Find suburb by id
    popup_item = driver.find_element_by_id(suburb_uid)

    # Select suburb
    popup_item.click()

    # Find GO button
    go_button = driver.find_element_by_class_name('gwt-SearchWidget-Button')

    # Click GO
    go_button.click()

# %%
# Function for getting the tables on html page
def get_tables(soup_html, id_content):
    content_tables = soup_html.find('div', attrs={'class':'content', 'id':id_content})
    return content_tables.find_all('table')

# %%
# Function for getting data from the tables and store in a dictionary
def scrape_stats(tables):
    data = {}
        
    for table in tables:
        
        table_rows = table.find_all('tr')
        table_name = table_rows[0].find('a', attrs={'class':'dictionaryLink'}).text        

        for i in range(1, len(table_rows)):
            
            try:
                row_label = table_rows[i].find('th', attrs={'class':'firstCol','scope':'row'}).text
            except(AttributeError):
                row_label = table_rows[i].find('th', attrs={'class':'firstCol'}).text

            count = table_rows[i].find_all('td')[0].text
            percentage = table_rows[i].find_all('td')[1].text

            data['{}_{}_{}'.format(table_name, row_label, 'count')] = count
            data['{}_{}_{}'.format(table_name, row_label, 'percentage')] = percentage
            
    return data

# %%
# Function combining get_tables and scrape_data functions
def get_stats(soup_html, id_content):
    tables = get_tables(soup_html, id_content)
    table_data = scrape_stats(tables)
    return table_data

# %%
# Function for getting quick stat tables
def get_qs_tables(soup_html):
    quick_stat_tables = soup_html.find('div', attrs={'id':'summaryTableAP'})
    return quick_stat_tables.find_all('table')

# %%
# Function for scraping quick stat tables
def scrape_qs(qs_tables):
    data = {}

    for qs_table in qs_tables:

        qs_table_rows = qs_table.find_all('tr')
        
        # Table labels and values for first row
        qs_table_name = qs_table_rows[0].find('th', attrs={'class':'addBold', 'scope':'row'}).text        
        qs_row_label = qs_table_name
        qs_row_value = qs_table_rows[0].find('td', attrs={'class':'summaryData'}).text

        data['{}_{}_{}'.format(qs_table_name, qs_row_label, 'count')] = qs_row_value
        
        # Table labels and values for second row and onwards
        for i in range(1, len(qs_table_rows)):
            
            qs_row_label = qs_table_rows[i].find('th', attrs={'scope':'row'}).text

            try:            
                qs_row_value = qs_table_rows[i].find('td', attrs={'class':'summaryData'}).text                
                if "%" in qs_row_value:            
                    data['{}_{}_{}'.format(qs_table_name, qs_row_label, 'percentage')] = qs_row_value        
                else:                          
                    data['{}_{}_{}'.format(qs_table_name, qs_row_label, 'count')] = qs_row_value                
            except(AttributeError):            
                pass
    
    # Change row label names
    data['Families_Avg children per family_for families with children_count'] = data.pop('Families_for families with children_count')
    data['Families_Avg children per family_for all families_count'] = data.pop('Families_for all families_count')
    
    data['All private dwellings_Average number of people per household_count'] = data.pop('All private dwellings_Average people per household_count')

    return data

# %%
# Function combining get_tables and scrape_data functions
def get_qs_stats(soup_html):
    qs_tables = get_qs_tables(soup_html)
    qs_table_data = scrape_qs(qs_tables)
    return qs_table_data

# %% [markdown]
# ### Get demographic data from Australian Bureau of Statistics

# %%
# Load file
aus_suburbs = pd.read_csv(os.path.join('aus_suburbs.csv'), index_col=0)

# %%
# Using Chrome to access web
driver = webdriver.Chrome()

driver.get('https://www.abs.gov.au/websitedbs/D3310114.nsf/Home/2016%20QuickStats')

# %%
# Using Chrome to access web
driver = webdriver.Chrome()

driver.get('https://www.abs.gov.au/websitedbs/D3310114.nsf/Home/2016%20QuickStats')

# ABS_data = {}

# for index,row in aus_suburbs.iterrows():
for i in range(1931, aus_suburbs.shape[0]):
    # Get suburb and state names from aus_suburbs table
#     suburb = row.Suburb
#     state = row.State
    suburb = aus_suburbs.iloc[i].Suburb
    state = aus_suburbs.iloc[i].State
    state = convert_to_acronym(state)

    print('{} {}'.format(suburb, state))

    while True:
        # Open the website
        driver.get('https://www.abs.gov.au/websitedbs/D3310114.nsf/Home/2016%20QuickStats')

        # Select census year
        year = '2016'
        census_cycle = driver.find_element_by_class_name('gwt-ListBox')
        census_year = census_cycle.find_element_by_xpath('//option[@value={}]'.format(year))
        census_year.click()

        # Go to suburb's ABS url page
        try:
            find_abs_quick_stat_webpage(suburb, state)
        except(Exception) as e:
            print('{} {} has no ABS page'.format(suburb, state))
            break
            
        # Get suburb's QuickStat URL
        url = driver.current_url

        # Get html page, title, and state from URL
        soup = BeautifulSoup(urlopen(url), "html.parser")
        
        page_state = soup.find('span', attrs={'class':'geoType'}).text
        page_state = page_state[12:]
        page_state = page_state.replace(' | State Suburbs','').replace(' | State Electoral Divisions','')
        page_state = convert_to_acronym(page_state)

        page_title = soup.title.text
        page_title = page_title.replace('2016 Census QuickStats: ', '')
        page_title = re.sub('[\(\[].*?[\)\]]', '', page_title)
        page_title = page_title.strip()

        print(soup.title.text)
        if (suburb == page_title) and (state == page_state):
            break
        else:
            print('Wrong page')
            continue

    # Scrape data from tables
    try:
        people = get_stats(soup, 'peopleContent')
        family = get_stats(soup, 'familyContent')
        dwelling = get_stats(soup, 'dwellingContent')
        ingp = get_stats(soup, 'INGPContent')

        # Merge datasets into one dictionary
        suburb_stats = {**people, **family, **dwelling, **ingp}

        # Add state as subkey
        suburb_stats['State'] = state

    except(AttributeError, NameError) as e:    
        # Scrape data that only have a quick stat table
        try:
            suburb_stats = get_qs_stats(soup)
            suburb_stats['State'] = state

        # Suburb does not contain any stats
        except(AttributeError):
            print(suburb)
            suburb_stats = {}

    # Add suburb dictionary to main dictionary
    ABS_data['{}_{}'.format(suburb,state)] = suburb_stats
# Out:
# Richmond Vic
# 1.7696191498063762
# Richmond
# 2016 Census QuickStats: Richmond (Northern Metropolitan)
# Richmond NSW
# 1.2590363988965012
# 2016 Census QuickStats: Richmond (NSW)
# Richmond Lowlands NSW
# 1.3244471122841812
# 2016 Census QuickStats: Richmond Lowlands
# Ridgehaven SA
# 1.1057350614385955
# 2016 Census QuickStats: Ridgehaven
# Ridgeway Tas
# 1.6494747376461278
# 2016 Census QuickStats: Ridgeway
# Ridgewood WA
# 1.6266758605044809
# 2016 Census QuickStats: Ridgewood (WA)
# Ridleyton SA
# 1.030489228158183
# 2016 Census QuickStats: Ridleyton
# Ringwood Vic
# 1.588044445134704
# 2016 Census QuickStats: Ringwood (Vic.)
# Ringwood East Vic
# 1.8852261604183755
# 2016 Census QuickStats: Ringwood East
# Ringwood North Vic
# 1.6509871893293762
# 2016 Census QuickStats: Ringwood North
# Ripley Qld
# 1.9589049458089758
# 2016 Census QuickStats: Ripley
# Ripponlea Vic
# 1.1517594187981544
# 2016 Census QuickStats: Ripponlea
# Risdon Tas
# 1.7448288767468128
# 2016 Census QuickStats: Risdon
# Risdon Vale Tas
# 1.2021928594953828
# 2016 Census QuickStats: Risdon Vale
# Riverhills Qld
# 1.8244833172824064
# 2016 Census QuickStats: Riverhills
# Riverstone NSW
# 1.3012234888573593
# 2016 Census QuickStats: Riverstone
# Riverton WA
# 1.3559344686130184
# 2016 Census QuickStats: Riverton (WA)
# Rivervale WA
# 1.890125802188398
# 2016 Census QuickStats: Lost River
# Wrong page
# 1.7226114320434096
# 2016 Census QuickStats: Rivervale
# Riverview Qld
# 1.181416073562131
# 2016 Census QuickStats: Lost River
# Wrong page
# 1.8795455350557584
# 2016 Census QuickStats: Riverview (Qld)
# Riverview NSW
# 1.4183513805856065
# 2016 Census QuickStats: Riverview (NSW)
# Riverwood NSW
# 1.8436864735092162
# 2016 Census QuickStats: Riverwood
# Rivett ACT
# 1.9347156308289795
# 2016 Census QuickStats: Lost River
# Wrong page
# 1.7289280222648165
# 2016 Census QuickStats: Rivett
# Robertson Qld
# 1.3318939226605468
# 2016 Census QuickStats: Robertson (Qld)
# Rochedale Qld
# 1.2836999348414269
# 2016 Census QuickStats: Rochedale
# Rochedale South Qld
# 1.8941400348595954
# 2016 Census QuickStats: Rochedale South
# Roches Beach Tas
# 1.3253137202793526
# 2016 Census QuickStats: Roches Beach
# Rockbank Vic
# 1.044846028109905
# 2016 Census QuickStats: Rockbank
# Rockdale NSW
# 1.6244791642232674
# 2016 Census QuickStats: Rockdale
# Rockingham WA
# 1.8261096318272507
# 2016 Census QuickStats: Gorge Rock
# Wrong page
# 1.2683675603296796
# 2016 Census QuickStats: Rockingham (WA)
# Rocklea Qld
# 1.4617391783819507
# 2016 Census QuickStats: Rocklea (Qld)
# Rocksberg Qld
# 1.0786287809951385
# 2016 Census QuickStats: Rocksberg
# Rodd Point NSW
# 1.5667068097356065
# 2016 Census QuickStats: Rodd Point
# Rokeby Tas
# 1.6061451480074145
# 2016 Census QuickStats: Rokeby (Tas.)
# Roleystone WA
# 1.7010488420505157
# 2016 Census QuickStats: Roleystone
# Rooty Hill NSW
# 1.3545901848635227
# 2016 Census QuickStats: Rooty Hill
# Ropes Crossing NSW
# 1.7193874640155102
# 2016 Census QuickStats: Ropes Crossing
# Rosanna Vic
# 1.2862800424188245
# 2016 Census QuickStats: Rosanna
# Rose Bay NSW
# 1.0101514743124453
# 2016 Census QuickStats: Rose Bay (NSW)
# Rose Bay Tas
# 1.684686786706581
# 2016 Census QuickStats: Rose Bay (Tas.)
# Rose Park SA
# 1.1363787966534444
# 2016 Census QuickStats: Rose Park
# Rosebery NT
# 1.0055522219439517
# 2016 Census QuickStats: Rose Valley (Snowy Monaro Regional - NSW)
# Wrong page
# 1.053451572024004
# 2016 Census QuickStats: Rosebery (NT)
# Rosebery NSW
# 1.0349656849700233
# 2016 Census QuickStats: Rosebery (NSW)
# Rosebud Vic
# 1.4598972554675267
# 2016 Census QuickStats: Rosebud
# Rosehill NSW
# 1.8765187374924281
# 2016 Census QuickStats: Rosehill (NSW)
# Roselands NSW
# 1.8725986405815598
# 2016 Census QuickStats: Roselands
# Rosemeadow NSW
# 1.4756997866818633
# 2016 Census QuickStats: Rosemeadow
# Rosetta Tas
# 1.3893556129622513
# 2016 Census QuickStats: Rosetta
# Roseville NSW
# 1.8074863732675723
# 2016 Census QuickStats: Roseville
# Roseville Chase NSW
# 1.7420934356122455
# 2016 Census QuickStats: Roseville Chase
# Rosewater SA
# 1.0399016315054652
# 2016 Census QuickStats: Rosewater
# Rosewood Qld
# 1.175261188759201
# 2016 Census QuickStats: Rosewood (Qld)
# Rosny Tas
# 1.241446817013443
# 2016 Census QuickStats: Rosny
# Rosny Park Tas
# 1.086902877484836
# 2016 Census QuickStats: Rosny Park
# Rosslyn Park SA
# 1.993674027380623
# 2016 Census QuickStats: Rosslyn Park
# Rossmore NSW
# 1.0409302922987989
# 2016 Census QuickStats: Rossmore (NSW)
# Rossmoyne WA
# 1.4635249951677003
# 2016 Census QuickStats: Rossmoyne
# Rostrevor SA
# 1.4043986537388533
# 2016 Census QuickStats: Rostrevor
# Rothwell Qld
# 1.6270699319767865
# 2016 Census QuickStats: Rothwell
# Rouse Hill NSW
# 1.4621295647519532
# 2016 Census QuickStats: Rouse Hill
# Rowville Vic
# 1.488574625035619
# 2016 Census QuickStats: Rowville
# Roxburgh Park Vic
# 1.4508221621214354
# 2016 Census QuickStats: Roxburgh Park
# Royal Park SA
# 1.872806598307863
# 2016 Census QuickStats: Royal Park
# Royston Park SA
# 1.2243595386805863
# 2016 Census QuickStats: Royston Park
# Rozelle NSW
# 1.7127566768744829
# 2016 Census QuickStats: Rozelle
# Runcorn Qld
# 1.5024326938552652
# 2016 Census QuickStats: Runcorn
# Ruse NSW
# 1.6039032444744166
# 2016 Census QuickStats: Ruse
# Rush Creek Qld
# 1.3132353546460616
# 2016 Census QuickStats: Rush Creek
# Rushcutters Bay NSW
# 1.1263754462012496
# 2016 Census QuickStats: Rushcutters Bay
# Russell Lea NSW
# 1.5844094209261181
# 2016 Census QuickStats: Russell Lea
# Rydalmere NSW
# 1.201201608718978
# 2016 Census QuickStats: Rydalmere
# Ryde NSW
# 1.2976494393723879
# 2016 Census QuickStats: Ryde
# Rye Vic
# 1.8468910637400389
# 2016 Census QuickStats: Rye
# Rythdale Vic
# 1.248895813849905
# 2016 Census QuickStats: Rythdale
# Sackville NSW
# 1.2697043654872848
# 2016 Census QuickStats: Sackville
# Sackville North NSW
# 1.0885222536981378
# 2016 Census QuickStats: Sackville North
# Sadleir NSW
# 1.121519976062273
# 2016 Census QuickStats: Sadleir
# Sadliers Crossing Qld
# 1.3854706660059275
# 2016 Census QuickStats: Sadliers Crossing
# Safety Bay WA
# 1.0652268127625872
# 2016 Census QuickStats: Safety Bay
# Safety Beach Vic
# 1.4601107332002314
# 2016 Census QuickStats: Safety Beach (Vic.)
# Salisbury SA
# 1.4343784967947575
# 2016 Census QuickStats: Salisbury (SA)
# Salisbury Qld
# 1.0361064842413867
# 2016 Census QuickStats: Salisbury (Qld)
# Salisbury Downs SA
# 1.0644084270831842
# 2016 Census QuickStats: Salisbury Downs
# Salisbury East SA
# 1.2599306763921225
# 2016 Census QuickStats: Salisbury East
# Salisbury Heights SA
# 1.5595070975046608
# 2016 Census QuickStats: Salisbury Heights
# Salisbury North SA
# 1.1930089858133832
# 2016 Census QuickStats: Salisbury North
# Salisbury Park SA
# 1.770558238290231
# 2016 Census QuickStats: Salisbury North
# Wrong page
# 1.8547825624067737
# 2016 Census QuickStats: Salisbury - Central
# Wrong page
# 1.2556969325613105
# 2016 Census QuickStats: Salisbury Park
# Salisbury Plain SA
# 1.9890582128237912
# 2016 Census QuickStats: Salisbury North
# Wrong page
# 1.1115075657124285
# 2016 Census QuickStats: Salisbury Plain
# Salisbury South SA
# 1.5293597263453393
# 2016 Census QuickStats: Salisbury East
# Wrong page
# 1.8519406334292716
# 2016 Census QuickStats: Salisbury South
# Salter Point WA
# 1.6617280234126675
# 2016 Census QuickStats: Salter Point
# Samford Valley Qld
# 1.5594790002661711
# 2016 Census QuickStats: Samford Valley
# Samford Village Qld
# 1.9113916593397984
# 2016 Census QuickStats: Samford Village
# Sampson Flat SA
# 1.3844502258011584
# 2016 Census QuickStats: Sampson Flat
# Samson WA
# 1.9653275959371648
# 2016 Census QuickStats: Samson
# Samsonvale Qld
# 1.8049834005925804
# 2016 Census QuickStats: Samsonvale
# Sandgate Qld
# 1.4344432772407751
# 2016 Census QuickStats: Sandgate (Qld)
# Sandhurst Vic
# 1.6107855107990718
# 2016 Census QuickStats: Sandhurst
# Sandringham Vic
# 1.7649318444844453
# 2016 Census QuickStats: Sandringham (Vic.)
# Sandringham NSW
# 1.7693065007030344
# 2016 Census QuickStats: Sandringham (NSW)
# Sandstone Point Qld
# 1.9491117400238958
# 2016 Census QuickStats: Sandstone Point
# Sandy Bay Tas
# 1.1257414539864392
# 2016 Census QuickStats: Sandy Bay
# Sandy Point NSW
# 1.079820350609033
# 2016 Census QuickStats: Sandy Point (NSW)
# Sans Souci NSW
# 1.607661244748992
# 2016 Census QuickStats: Sans Souci
# Sassafras Vic
# 1.263294672258759
# 2016 Census QuickStats: Sassafras (Vic.)
# Sawyers Valley WA
# 1.2345676906867726
# 2016 Census QuickStats: Sawyers Valley
# Scarborough WA
# 1.836474893517249
# Scarborough WA has no ABS page
# Scarborough Qld
# 1.9500611040333622
# 2016 Census QuickStats: Scarborough (Qld)
# Scheyville NSW
# 1.2651229142141351
# 2016 Census QuickStats: Scheyville
# Schofields NSW
# 1.1424653548144477
# 2016 Census QuickStats: Schofields
# Scoresby Vic
# 1.1475178979462621
# 2016 Census QuickStats: Scoresby
# Scullin ACT
# 1.7280275578378674
# 2016 Census QuickStats: Scullin
# Seabrook Vic
# 1.859096305913611
# 2016 Census QuickStats: Seabrook
# Seacliff SA
# 1.8121293985321167
# 2016 Census QuickStats: Seacliff
# Seacliff Park SA
# 1.8233166672090755
# 2016 Census QuickStats: Seacliff Park
# Seacombe Gardens SA
# 1.8189059018378488
# 2016 Census QuickStats: Seacombe Gardens
# Seacombe Heights SA
# 1.7310171670432997
# 2016 Census QuickStats: Seacombe Heights
# Seaford Vic
# 1.1809507808492121
# 2016 Census QuickStats: Seaford (Vic.)
# Seaford SA
# 1.7593937978953316
# 2016 Census QuickStats: Seaford (SA)
# Seaford Heights SA
# 1.9476883067057842
# 2016 Census QuickStats: Seaford Heights
# Seaford Meadows SA
# 1.6786034608014029
# 2016 Census QuickStats: Seaford Meadows
# Seaford Rise SA
# 1.0477523551655978
# 2016 Census QuickStats: Seaford Rise
# Seaforth NSW
# 1.242355990238297
# Seaforth NSW has no ABS page
# Seaholme Vic
# 1.1921830120056292
# 2016 Census QuickStats: Seaholme
# Seaton SA
# 1.4127539836013927
# 2016 Census QuickStats: Seaton (SA)
# Seaview Downs SA
# 1.3027609043038006
# 2016 Census QuickStats: Seaview Downs
# Secret Harbour WA
# 1.7208022420962514
# 2016 Census QuickStats: Secret Harbour
# Seddon Vic
# 1.0161301209533244
# 2016 Census QuickStats: Seddon (Vic.)
# Sefton NSW
# 1.4783724978065367
# 2016 Census QuickStats: Sefton
# Sefton Park SA
# 1.809970780179294
# 2016 Census QuickStats: Sefton Park
# Selby Vic
# 1.1797929998276069
# 2016 Census QuickStats: Selby
# Sellicks Beach SA
# 1.7440166438253848
# 2016 Census QuickStats: Sellicks Beach
# Sellicks Hill SA
# 1.1778013442081918
# 2016 Census QuickStats: Sellicks Hill
# Semaphore SA
# 1.8863436067633246
# 2016 Census QuickStats: Semaphore
# Semaphore Park SA
# 1.456582884624567
# 2016 Census QuickStats: Semaphore Park
# Semaphore South SA
# 1.7524013280901074
# 2016 Census QuickStats: Semaphore South
# Serpentine WA
# 1.2731080833818953
# 2016 Census QuickStats: Serpentine (WA)
# Seven Hills NSW
# 1.4173158226701013
# 2016 Census QuickStats: Seven Hills (NSW)
# Seven Hills Qld
# 1.8879333620659113
# 2016 Census QuickStats: Seven Hills (Qld)
# Seventeen Mile Rocks Qld
# 1.4356400503162163
# 2016 Census QuickStats: Seventeen Mile Rocks
# Seville Vic
# 1.3776241651047014
# 2016 Census QuickStats: Seville
# Seville East Vic
# 1.0795535832089174
# 2016 Census QuickStats: Seville East
# Seville Grove WA
# 1.9259338297505528
# 2016 Census QuickStats: Seville Grove
# Shailer Park Qld
# 1.4617332471193882
# 2016 Census QuickStats: Shailer Park
# Shalvey NSW
# 1.2839975270638502
# 2016 Census QuickStats: Shalvey
# Shanes Park NSW
# 1.2454583870204972
# 2016 Census QuickStats: Shanes Park
# Sheidow Park SA
# 1.9250349085152596
# 2016 Census QuickStats: Sheidow Park
# Sheldon Qld
# 1.8632397511034435
# 2016 Census QuickStats: Sheldon
# Shelley WA
# 1.1569714115822047
# 2016 Census QuickStats: Shelley (WA)
# Shenton Park WA
# 1.3313871024569122
# 2016 Census QuickStats: Shenton Park
# Sherbrooke Vic
# 1.7673099532091532
# 2016 Census QuickStats: Sherbrooke
# Sherwood Qld
# 1.3117425752414071
# 2016 Census QuickStats: Sherwood (Qld)
# Shoalwater WA
# 1.1067478757794358
# 2016 Census QuickStats: Shoalwater (WA)
# Shoreham Vic
# 1.881644475232949
# 2016 Census QuickStats: Shoreham
# Shorncliffe Qld
# 1.030576579372819
# 2016 Census QuickStats: Shorncliffe
# Silkstone Qld
# 1.9842321900397033
# 2016 Census QuickStats: Silkstone
# Silvan Vic
# 1.4241457578486232
# 2016 Census QuickStats: Silvan
# Silverwater NSW
# 1.572893940200218
# 2016 Census QuickStats: Silverwater (Lake Macquarie - NSW)
# Sinagra WA
# 1.6367281323145626
# 2016 Census QuickStats: Sinagra
# Singleton WA
# 1.3922232061630648
# 2016 Census QuickStats: Singleton (WA)
# Sinnamon Park Qld
# 1.8768236471149067
# 2016 Census QuickStats: Sinnamon Park
# Skye Vic
# 1.515176556691203
# 2016 Census QuickStats: Skye (Vic.)
# Skye SA
# 1.263092739341019
# 2016 Census QuickStats: Skye (SA)
# Slacks Creek Qld
# 1.0941381401770534
# 2016 Census QuickStats: Slacks Creek
# Smeaton Grange NSW
# 1.3410325382653907
# 2016 Census QuickStats: Smeaton Grange
# Smithfield SA
# 1.575912395444096
# 2016 Census QuickStats: Smithfield (SA)
# Smithfield NSW
# 1.0137954704422345
# 2016 Census QuickStats: Smithfield (NSW)
# Smithfield Plains SA
# 1.0376091753922783
# 2016 Census QuickStats: Smithfield Plains
# Smiths Gully Vic
# 1.4675048992976059
# 2016 Census QuickStats: Smiths Gully
# Somers Vic
# 1.0896461308293461
# 2016 Census QuickStats: Somers
# Somerton Vic
# 1.536342857717047
# 2016 Census QuickStats: Somerton (Vic.)
# Somerton
# Somerton Park SA
# 1.305697972814421
# 2016 Census QuickStats: Somerton Park
# Somerville Vic
# 1.4058907919850867
# 2016 Census QuickStats: Somerville (Vic.)
# Sorell Tas
# 1.3413137269884747
# 2016 Census QuickStats: Sorell
# Sorrento WA
# 1.6034959567217035
# 2016 Census QuickStats: Sorrento (WA)
# Sorrento Vic
# 1.877477112919828
# 2016 Census QuickStats: Sorrento (Vic.)
# South Brighton SA
# 1.310417816544919
# 2016 Census QuickStats: South Brighton
# South Brisbane Qld
# 1.8213257157665272
# 2016 Census QuickStats: South Brisbane
# South Coogee NSW
# 1.1075831711330761
# 2016 Census QuickStats: South Coogee
# South Fremantle WA
# 1.705712792481189
# 2016 Census QuickStats: South Fremantle
# South Granville NSW
# 1.635261196197789
# 2016 Census QuickStats: South Granville
# South Guildford WA
# 1.039053866091642
# 2016 Census QuickStats: South Guildford
# South Hobart Tas
# 1.5953499689892334
# 2016 Census QuickStats: South Hobart
# South Hurstville NSW
# 1.5317471089331747
# 2016 Census QuickStats: South Hurstville
# South Kingsville Vic
# 1.2471387100669107
# 2016 Census QuickStats: South Kingsville
# South Lake WA
# 1.729423413408612
# 2016 Census QuickStats: South Lake
# South Maclean Qld
# 1.2532369930278453
# 2016 Census QuickStats: South Maclean
# South Maroota NSW
# 1.966598880939384
# 2016 Census QuickStats: South Maroota
# South Melbourne Vic
# 1.3978345489988042
# 2016 Census QuickStats: South Melbourne
# South Morang Vic
# 1.7292519987707187
# 2016 Census QuickStats: South Morang
# South Penrith NSW
# 1.6637344114902208
# 2016 Census QuickStats: South Penrith
# South Perth WA
# 1.2403454913054146
# 2016 Census QuickStats: South Perth
# South Plympton SA
# 1.7782575036380166
# 2016 Census QuickStats: South Plympton
# South Ripley Qld
# 1.8107043920900132
# 2016 Census QuickStats: Kotara South
# Wrong page
# 1.1709307054520193
# 2016 Census QuickStats: South Ripley
# South Turramurra NSW
# 1.8024435772711924
# 2016 Census QuickStats: South Turramurra
# South Wentworthville NSW
# 1.3032002475228186
# 2016 Census QuickStats: South Wentworthville
# South Wharf Vic
# 1.7062423753393134
# 2016 Census QuickStats: South Wharf
# South Windsor NSW
# 1.8246246572059446
# 2016 Census QuickStats: Kotara South
# Wrong page
# 1.3585890120069162
# 2016 Census QuickStats: South Windsor
# South Yarra Vic
# 1.6082863707125217
# 2016 Census QuickStats: South Yarra
# Southbank Vic
# 1.3904942726529679
# 2016 Census QuickStats: Belmont South
# Wrong page
# 1.1715331124078416
# 2016 Census QuickStats: Kotara South
# Wrong page
# 1.2437090896938952
# 2016 Census QuickStats: Southbank
# Southern River WA
# 1.68362553628989
# 2016 Census QuickStats: Southern River
# Southport NT
# 1.0004790962924814
# 2016 Census QuickStats: Southport (NT)
# Spearwood WA
# 1.7368747411484735
# 2016 Census QuickStats: Spearwood
# Spence ACT
# 1.0901472011671625
# 2016 Census QuickStats: Spence (ACT)
# Spotswood Vic
# 1.2886025984787568
# 2016 Census QuickStats: Spotswood
# Spring Farm NSW
# 1.1960871763918683
# 2016 Census QuickStats: Spring Farm (NSW)
# Spring Hill Qld
# 1.895203715129521
# 2016 Census QuickStats: Spring Hill (Qld)
# Spring Mountain Qld
# 1.0008249111841554
# 2016 Census QuickStats: Spring Mountain (Qld)
# Spring Mountain
# Springfield Qld
# 1.7819311783965066
# 2016 Census QuickStats: Springfield (Ipswich - Qld)
# Springfield SA
# 1.4511745337069404
# 2016 Census QuickStats: Springfield (SA)
# Springfield Central Qld
# 1.2793495067540999
# 2016 Census QuickStats: Springfield Central
# Springfield Lakes Qld
# 1.4189832869182424
# 2016 Census QuickStats: Springfield Lakes
# Springvale Vic
# 1.3746327378565608
# 2016 Census QuickStats: Springvale (Vic.)
# Springvale South Vic
# 1.2174632712545073
# 2016 Census QuickStats: Springvale South
# Springwood Qld
# 1.5073782711999537
# 2016 Census QuickStats: Springwood (Qld)
# St Agnes SA
# 1.641738444724099
# 2016 Census QuickStats: St Agnes (SA)
# St Albans Vic
# 1.1087628745591545
# 2016 Census QuickStats: St Albans (Vic.)
# St Andrews NSW
# 1.423543159640517
# 2016 Census QuickStats: St Andrews (NSW)
# St Andrews Beach Vic
# 1.066943374171265
# 2016 Census QuickStats: St Andrews Beach
# St Clair SA
# 1.2357303618137987
# 2016 Census QuickStats: St Clair (SA)
# St Clair NSW
# 1.8141564210381396
# 2016 Census QuickStats: St Clair (Penrith - NSW)
# St Georges SA
# 1.1624118516369124
# 2016 Census QuickStats: St Georges
# St Helena Vic
# 1.9298476300220684
# 2016 Census QuickStats: St Helena
# St Helens Park NSW
# 1.6001637737192462
# 2016 Census QuickStats: St Helens Park
# St Ives NSW
# 1.5395952521799852
# 2016 Census QuickStats: St Ives (NSW)
# St Ives Chase NSW
# 1.3218487902384983
# 2016 Census QuickStats: St Ives Chase
# St James WA
# 1.8718037792464868
# 2016 Census QuickStats: St James (WA)
# St Johns Park NSW
# 1.6242758344146044
# 2016 Census QuickStats: St Johns Park
# St Kilda SA
# 1.396354302906209
# 2016 Census QuickStats: St Andrews (Vic.)
# Wrong page
# 1.00238862489453
# 2016 Census QuickStats: St Kilda (SA)
# St Kilda Vic
# 1.6813631615704894
# 2016 Census QuickStats: St Kilda (Vic.)
# St Kilda East Vic
# 1.830117350428035
# 2016 Census QuickStats: St Kilda East
# St Kilda West Vic
# 1.6582297533317902
# 2016 Census QuickStats: St Kilda West
# St Leonards NSW
# 1.395244521313501
# 2016 Census QuickStats: St Leonards (NSW)
# St Lucia Qld
# 1.7716123306271987
# 2016 Census QuickStats: St Lucia
# St Marys SA
# 1.797202398201685
# 2016 Census QuickStats: St Marys (SA)
# St Marys NSW
# 1.8259250080586455
# 2016 Census QuickStats: St Marys (NSW)
# St Morris SA
# 1.1918238984112501
# 2016 Census QuickStats: St Morris
# St Peters NSW
# 1.5790272045719067
# 2016 Census QuickStats: St Peters (NSW)
# St Peters SA
# 1.4983367420841742
# 2016 Census QuickStats: St Peters (SA)
# Stafford Qld
# 1.0202474408949564
# 2016 Census QuickStats: Stafford
# Stafford Heights Qld
# 1.3881817123410487
# 2016 Census QuickStats: Stafford Heights
# Stanhope Gardens NSW
# 1.425996993671121
# 2016 Census QuickStats: Stanhope Gardens
# Stanmore Qld
# 1.2477394240991861
# 2016 Census QuickStats: Stanmore (Qld)
# Stanmore NSW
# 1.8071441205046237
# 2016 Census QuickStats: Stanmore (NSW)
# Steels Creek Vic
# 1.6564437316968936
# 2016 Census QuickStats: Steels Creek
# Stepney SA
# 1.9325992319687026
# 2016 Census QuickStats: Stepney
# Stirling WA
# 1.0592060497260847
# 2016 Census QuickStats: Stirling (WA)
# Stirling ACT
# 1.3149342297126991
# 2016 Census QuickStats: Stirling (ACT)
# Stirling SA
# 1.6904444810431736
# 2016 Census QuickStats: Stirling (SA)
# Stockleigh Qld
# 1.2243776554730434
# 2016 Census QuickStats: Stockleigh
# Stones Corner Qld
# 1.2923209693095112
# Stones Corner Qld has no ABS page
# Stoneville WA
# 1.6604827049471254
# 2016 Census QuickStats: Stoneville
# Stony Creek Qld
# 1.2979730510421654
# 2016 Census QuickStats: Stony Creek (Qld)
# Stonyfell SA
# 1.7209831996239275
# 2016 Census QuickStats: Stonnington - East
# Wrong page
# 1.7345596129635252
# 2016 Census QuickStats: Stonyfell
# Strathewen Vic
# 1.7365892791898594
# 2016 Census QuickStats: Strathewen
# Strathfield NSW
# 1.4524341291741973
# 2016 Census QuickStats: Strathfield (NSW)
# Strathfield South NSW
# 1.783998717580696
# 2016 Census QuickStats: Strathfield South
# Strathmore Vic
# 1.374393250654407
# 2016 Census QuickStats: Strathmore (Vic.)
# Strathmore Heights Vic
# 1.351208971667593
# 2016 Census QuickStats: Strathmore Heights
# Strathpine Qld
# 1.6968211021385182
# 2016 Census QuickStats: Strathpine
# Stratton WA
# 1.5135714635713675
# 2016 Census QuickStats: Stratton
# Stretton Qld
# 1.8988214039721862
# 2016 Census QuickStats: Stretton
# Stuart Park NT
# 1.4303340838785958
# 2016 Census QuickStats: Stuart Park
# Sturt SA
# 1.6138324676134208
# 2016 Census QuickStats: Sturt (SA)
# Subiaco WA
# 1.0763258206193596
# 2016 Census QuickStats: Subiaco
# Success WA
# 1.5879341866848478
# 2016 Census QuickStats: Success
# Summer Hill NSW
# 1.8923099486184078
# 2016 Census QuickStats: Summer Hill (Dungog - NSW)
# Sumner Qld
# 1.619979139125714
# 2016 Census QuickStats: Sumner
# Sunbury Vic
# 1.1842966859571826
# 2016 Census QuickStats: Sunbury
# Sunnybank Qld
# 1.4755329497462881
# 2016 Census QuickStats: Sunnybank
# Sunnybank Hills Qld
# 1.5878465591154112
# 2016 Census QuickStats: Sunnybank Hills
# Sunshine Vic
# 1.4222171458965964
# 2016 Census QuickStats: Sunshine (Vic.)
# Sunshine North Vic
# 1.5479750561431365
# 2016 Census QuickStats: Sunshine North
# Sunshine West Vic
# 1.8795687712685474
# 2016 Census QuickStats: Sunshine West
# Surrey Downs SA
# 1.4051767919955518
# 2016 Census QuickStats: Surrey Downs
# Surrey Hills Vic
# 1.6000719741872365
# 2016 Census QuickStats: Surrey Hills
# Surry Hills NSW
# 1.8212742336203371
# 2016 Census QuickStats: Surry Hills
# Sutherland NSW
# 1.2639063729905566
# 2016 Census QuickStats: Sutherland (NSW)
# Swan View WA
# 1.5998071551657973
# 2016 Census QuickStats: Swan View
# Swanbourne WA
# 1.6533600159389024
# 2016 Census QuickStats: Swanbourne
# Sydenham Vic
# 1.2583752442667129
# 2016 Census QuickStats: Sydenham (Vic.)
# Sydenham NSW
# 1.4864763474975635
# 2016 Census QuickStats: Sydenham (NSW)
# Sydney Olympic Park NSW
# 1.7822780075897744
# 2016 Census QuickStats: Sydney Olympic Park
# Sylvania NSW
# 1.1210023340691366
# 2016 Census QuickStats: Sylvania
# Sylvania Waters NSW
# 1.7660644693457974
# 2016 Census QuickStats: Sylvania Waters
# Symonston ACT
# 1.9925640195891927
# 2016 Census QuickStats: Symonston
# Taigum Qld
# 1.3296231742396711
# 2016 Census QuickStats: Taigum
# Tallegalla Qld
# 1.5977852437342226
# 2016 Census QuickStats: Tallegalla
# Tamala Park WA
# 1.6483920028209047
# 2016 Census QuickStats: Tamala Park
# Tamala Park
# Tamarama NSW
# 1.7394097593836828
# 2016 Census QuickStats: Tamarama
# Tamborine Qld
# 1.5856526779395304
# 2016 Census QuickStats: Tamborine
# Tanah Merah Qld
# 1.5625880287039031
# 2016 Census QuickStats: Tanah Merah
# Taperoo SA
# 1.4064767142107786
# 2016 Census QuickStats: Taperoo
# Tapping WA
# 1.0764079386658878
# 2016 Census QuickStats: Tapping
# Taren Point NSW
# 1.909440348644646
# 2016 Census QuickStats: Taren Point
# Taringa Qld
# 1.9380398698558783
# 2016 Census QuickStats: Taringa
# Tarneit Vic
# 1.5944572001721533
# 2016 Census QuickStats: Tarneit
# Taroona Tas
# 1.6710750128047382
# 2016 Census QuickStats: Tarampa
# Wrong page
# 1.350883787275143
# 2016 Census QuickStats: Taroona
# Tarragindi Qld
# 1.1506150745861574
# 2016 Census QuickStats: Tarampa
# Wrong page
# 1.1371617332441328
# 2016 Census QuickStats: Tarragindi
# Tarrawarra Vic
# 1.0950878754688071
# 2016 Census QuickStats: Tarrawarra
# Taylors Hill Vic
# 1.188366719140969
# 2016 Census QuickStats: Taylors Hill
# Taylors Lakes Vic
# 1.196167492187608
# 2016 Census QuickStats: Taylors Lakes
# Tea Tree Gully SA
# 1.7151642693240734
# 2016 Census QuickStats: Tea Tree Gully
# Tecoma Vic
# 1.529160485109971
# 2016 Census QuickStats: Tecoma
# Telopea NSW
# 1.1748574909591287
# 2016 Census QuickStats: Telopea
# Tempe NSW
# 1.0152832986679594
# 2016 Census QuickStats: Tempe
# Templestowe Vic
# 1.3734596029795276
# 2016 Census QuickStats: Templestowe
# Templestowe Lower Vic
# 1.0303256420204647
# 2016 Census QuickStats: Templestowe Lower
# Teneriffe Qld
# 1.2339072452511441
# 2016 Census QuickStats: Teneriffe
# Tennyson SA
# 1.5389979310535853
# 2016 Census QuickStats: Tennyson (SA)
# Tennyson Qld
# 1.5284928754931844
# 2016 Census QuickStats: Tennyson (Qld)
# Tennyson NSW
# 1.9545232944257638
# 2016 Census QuickStats: Tennyson (NSW)
# Tennyson Point NSW
# 1.3977201901540133
# 2016 Census QuickStats: Tennyson Point
# Terrey Hills NSW
# 1.6488927469988908
# 2016 Census QuickStats: Terrey Hills
# Thagoona Qld
# 1.6128407515795675
# 2016 Census QuickStats: Thagoona
# The Basin Vic
# 1.1110940850298037
# 2016 Census QuickStats: The Basin (Vic.)
# The Gap Qld
# 1.2533343005647415
# 2016 Census QuickStats: The Gap (Brisbane - Qld)
# The Gardens NT
# 1.3214564748083872
# 2016 Census QuickStats: The Gardens (NT)
# The Lakes WA
# 1.3225091094714736
# 2016 Census QuickStats: The Lakes
# The Narrows NT
# 1.316237786112548
# 2016 Census QuickStats: The Narrows (NT)
# The Patch Vic
# 1.9258122484700473
# 2016 Census QuickStats: The Patch
# The Ponds NSW
# 1.484171097880763
# 2016 Census QuickStats: The Ponds
# The Range SA
# 1.6761784091367251
# 2016 Census QuickStats: The Range (SA)
# The Rocks NSW
# 1.8232769178247312
# 2016 Census QuickStats: The Rocks (Bathurst Regional - NSW)
# The Slopes NSW
# 1.937115373273071
# 2016 Census QuickStats: The Slopes
# The Vines WA
# 1.9071741021096118
# 2016 Census QuickStats: The Vines
# Thebarton SA
# 1.3042888330878064
# 2016 Census QuickStats: Thebarton
# Theodore ACT
# 1.9576089481535703
# 2016 Census QuickStats: Theodore (ACT)
# Thomastown Vic
# 1.8657262148077152
# 2016 Census QuickStats: Thomastown
# Thornbury Vic
# 1.377705101924079
# 2016 Census QuickStats: Thornbury
# Thorneside Qld
# 1.3658292535112544
# 2016 Census QuickStats: Thorneside
# Thorngate SA
# 1.989114405748352
# 2016 Census QuickStats: Thorngate
# Thornlands Qld
# 1.573571679489478
# 2016 Census QuickStats: Mount Thorley
# Wrong page
# 1.2408029339709834
# 2016 Census QuickStats: Thornlands
# Thornleigh NSW
# 1.2665932673258622
# 2016 Census QuickStats: Thornleigh
# Thornlie WA
# 1.737910138456006
# 2016 Census QuickStats: Thornlie
# Three Bridges Vic
# 1.2771845696848114
# 2016 Census QuickStats: Three Bridges
# Tingalpa Qld
# 1.0583823710869962
# 2016 Census QuickStats: Tingalpa
# Tivendale NT
# 1.0502741504892557
# 2016 Census QuickStats: Tivendale
# Tivendale
# Tivoli Qld
# 1.3010402481128298
# 2016 Census QuickStats: Tivoli
# Tiwi NT
# 1.1272101497707308
# 2016 Census QuickStats: Tiwi
# Tolmans Hill Tas
# 1.092153319491981
# 2016 Census QuickStats: Tolmans Hill
# Tonimbuk Vic
# 1.1263956096956416
# 2016 Census QuickStats: Tonimbuk
# Toolern Vale Vic
# 1.700777324355435
# 2016 Census QuickStats: Toolern Vale
# Toongabbie NSW
# 1.529786826273806
# 2016 Census QuickStats: Toongabbie (NSW)
# Tooradin Vic
# 1.8664577017545696
# 2016 Census QuickStats: Tooradin
# Toorak Vic
# 1.4960061401044427
# 2016 Census QuickStats: Toorak
# Toorak Gardens SA
# 1.7556683603755618
# 2016 Census QuickStats: Toorak Gardens
# Toorbul Qld
# 1.3479258655466468
# 2016 Census QuickStats: Toorbul
# Tootgarook Vic
# 1.8247132932386831
# 2016 Census QuickStats: Tootgarook
# Torrens ACT
# 1.9329311951532513
# 2016 Census QuickStats: Torrens
# Torrens Park SA
# 1.2979516384261256
# 2016 Census QuickStats: Torrens Park
# Torrensville SA
# 1.732024690735293
# 2016 Census QuickStats: Torrensville
# Tottenham Vic
# 1.6768672509294795
# 2016 Census QuickStats: Tottenham (Vic.)
# Tottenham
# Tranmere Tas
# 1.0900275044911059
# 2016 Census QuickStats: Tranmere (Tas.)
# Tranmere SA
# 1.759997112624422
# 2016 Census QuickStats: Tranmere (SA)
# Travancore Vic
# 1.728063660696588
# 2016 Census QuickStats: Travancore
# Tregear NSW
# 1.3789668950118974
# 2016 Census QuickStats: Fern Tree (L)
# Wrong page
# 1.621879725282415
# 2016 Census QuickStats: Tregear
# Tremont Vic
# 1.0129206763452667
# 2016 Census QuickStats: Tremont
# Trigg WA
# 1.27801479146996
# 2016 Census QuickStats: Trigg
# Trinity Gardens SA
# 1.0357974042385485
# 2016 Census QuickStats: Trinity Gardens
# Trott Park SA
# 1.9569997466310713
# 2016 Census QuickStats: Trott Park
# Truganina Vic
# 1.0314636583725036
# 2016 Census QuickStats: Truganina
# Tuart Hill WA
# 1.0042723478880906
# 2016 Census QuickStats: Tuart Hill
# Tuerong Vic
# 1.8815327765695455
# 2016 Census QuickStats: Tuerong
# Tullamarine Vic
# 1.5035788612051877
# 2016 Census QuickStats: Tullamarine
# Tumbling Waters NT
# 1.8525081814203435
# 2016 Census QuickStats: Tumbling Waters
# Turner ACT
# 1.8063025107107036
# 2016 Census QuickStats: Turner
# Turramurra NSW
# 1.2072337323712476
# 2016 Census QuickStats: Turramurra
# Turrella NSW
# 1.4217893577024097
# 2016 Census QuickStats: Turoar
# Wrong page
# 1.3803342639863903
# 2016 Census QuickStats: Turrella
# Tusmore SA
# 1.781179959247075
# 2016 Census QuickStats: Tusmore
# Two Rocks WA
# 1.7711381434937543
# 2016 Census QuickStats: Two Rocks
# Tyabb Vic
# 1.7144225653081344
# 2016 Census QuickStats: Tyabb
# Tynong Vic
# 1.7038019640895228
# 2016 Census QuickStats: Tynong
# Tynong North Vic
# 1.5628207132650118
# 2016 Census QuickStats: Tynong North
# Uleybury SA
# 1.1725304062531003
# 2016 Census QuickStats: Uleybury
# Ultimo NSW
# 1.7760480219157557
# 2016 Census QuickStats: Ultimo
# Underdale SA
# 1.8690431908090421
# 2016 Census QuickStats: Underdale
# Underwood Qld
# 1.7434386847734056
# 2016 Census QuickStats: Underwood (Qld)
# Undullah Qld
# 1.4608876667245978
# 2016 Census QuickStats: Undullah
# Unley SA
# 1.1259946559800675
# 2016 Census QuickStats: Unley
# Unley Park SA
# 1.1516598149784347
# 2016 Census QuickStats: Unley Park
# Upper Brookfield Qld
# 1.9511863688530173
# 2016 Census QuickStats: Upper Brookfield
# Upper Caboolture Qld
# 1.953166167880533
# 2016 Census QuickStats: Upper Caboolture
# Upper Ferntree Gully Vic
# 1.6353800455081686
# 2016 Census QuickStats: Upper Ferntree Gully
# Upper Hermitage SA
# 1.042171256639432
# 2016 Census QuickStats: Upper Hermitage
# Upper Kedron Qld
# 1.4168529586692111
# 2016 Census QuickStats: Upper Kedron
# Upper Mount Gravatt Qld
# 1.0966338531471476
# 2016 Census QuickStats: Upper Mount Gravatt
# Upper Sturt SA
# 1.5284436210155143
# 2016 Census QuickStats: Upper Sturt
# Upper Swan WA
# 1.625037098371471
# 2016 Census QuickStats: Upper Swan
# Upwey Vic
# 1.0582483923067512
# 2016 Census QuickStats: Upwey
# Urrbrae SA
# 1.1534512840257336
# 2016 Census QuickStats: Urrbrae
# Vale Park SA
# 1.8166986773584868
# 2016 Census QuickStats: Vale Park
# Valley View SA
# 1.8240522560701407
# 2016 Census QuickStats: Valley View
# Varroville NSW
# 1.5689467353615583
# 2016 Census QuickStats: Varroville
# Vaucluse NSW
# 1.9328974250993327
# 2016 Census QuickStats: Vaucluse
# Veresdale Qld
# 1.0944483050691833
# 2016 Census QuickStats: Veresdale
# Veresdale Scrub Qld
# 1.9639048914261223
# 2016 Census QuickStats: Veresdale Scrub
# Vermont Vic
# 1.4983689272020864
# 2016 Census QuickStats: Vermont
# Vermont South Vic
# 1.9558609245717489
# 2016 Census QuickStats: Vermont South
# Vervale Vic
# 1.277708478678913
# 2016 Census QuickStats: Vervale
# Victoria Park WA
# 1.1562796824396528
# 2016 Census QuickStats: Victoria Park
# Victoria Point Qld
# 1.4685144445987484
# 2016 Census QuickStats: Victoria Point (Qld)
# Viewbank Vic
# 1.3452744241563575
# 2016 Census QuickStats: Viewbank
# Villawood NSW
# 1.7334569049221407
# 2016 Census QuickStats: Villawood
# Vineyard NSW
# 1.4615953651031484
# 2016 Census QuickStats: Vineyard
# Virginia Qld
# 1.7329053917731847
# 2016 Census QuickStats: Virginia (Qld)
# Virginia NT
# 1.909671088507722
# 2016 Census QuickStats: Virginia (NT)
# Virginia SA
# 1.470379056835446
# 2016 Census QuickStats: Virginia (SA)
# Vista SA
# 1.5003953110737833
# 2016 Census QuickStats: Vista
# Viveash WA
# 1.630396587639062
# 2016 Census QuickStats: Viveash
# Voyager Point NSW
# 1.2849740881443976
# 2016 Census QuickStats: Voyager Point
# Wacol Qld
# 1.7707212617244223
# 2016 Census QuickStats: Wacol
# Wagait Beach NT
# 1.0132096774302883
# 2016 Census QuickStats: Wagait Beach
# Wagaman NT
# 1.5841901582350268
# 2016 Census QuickStats: Wagaman
# Waikiki WA
# 1.338700617613497
# 2016 Census QuickStats: Waikiki
# Waitara NSW
# 1.6372860679492502
# 2016 Census QuickStats: Waitara
# Wakeley NSW
# 1.3012526756540441
# 2016 Census QuickStats: Wakeley
# Wakerley Qld
# 1.0028407524196863
# 2016 Census QuickStats: Wakerley
# Walkerville SA
# 1.9174369900769044
# 2016 Census QuickStats: Walkerville (SA)
# Wallacia NSW
# 1.2616035619257162
# 2016 Census QuickStats: Wallacia
# Walliston WA
# 1.8629617818974422
# 2016 Census QuickStats: Walliston
# Walloon Qld
# 1.5889612847434853
# 2016 Census QuickStats: Walloon
# Wamuran Qld
# 1.002839614268065
# 2016 Census QuickStats: Wamuran
# Wamuran Basin Qld
# 1.5082717859567034
# 2016 Census QuickStats: Wamuran Basin
# Wandi WA
# 1.8771837056581213
# 2016 Census QuickStats: Wandi
# Wandin East Vic
# 1.523484634046702
# 2016 Census QuickStats: Wandin East
# Wandin North Vic
# 1.4958588400599409
# 2016 Census QuickStats: Wandin North
# Wangara WA
# 1.0735095691601262
# 2016 Census QuickStats: Wangara
# Wanguri NT
# 1.7357838413459592
# 2016 Census QuickStats: Wanguri
# Wanniassa ACT
# 1.2010634874195971
# 2016 Census QuickStats: Wanniassa
# Wantirna Vic
# 1.9214851693977382
# 2016 Census QuickStats: Wantirna
# Wantirna South Vic
# 1.5443404494769064
# 2016 Census QuickStats: Wantirna South
# Waramanga ACT
# 1.9773537645739951
# 2016 Census QuickStats: Waramanga
# Warburton Vic
# 1.2315828627927021
# 2016 Census QuickStats: Warburton (Vic.)
# Wareemba NSW
# 1.136212038437805
# 2016 Census QuickStats: Wareemba
# Warnbro WA
# 1.6216292912231873
# 2016 Census QuickStats: Warnbro
# Warneet Vic
# 1.0019236273018084
# 2016 Census QuickStats: Warneet
# Warner Qld
# 1.1263406499362003
# 2016 Census QuickStats: Warner
# Warradale SA
# 1.9626907755584155
# 2016 Census QuickStats: Warradale
# Warrandyte Vic
# 1.400694094281509
# 2016 Census QuickStats: Warragai Creek
# Wrong page
# 1.7221965717777639
# 2016 Census QuickStats: Warragai Creek
# Wrong page
# 1.2470452539307968
# 2016 Census QuickStats: Warrandyte
# Warrandyte South Vic
# 1.518809848668905
# 2016 Census QuickStats: Warrandyte South
# Warrane Tas
# 1.3191020325475529
# 2016 Census QuickStats: Warragai Creek
# Wrong page
# 1.9987139731198318
# 2016 Census QuickStats: Warrane
# Warranwood Vic
# 1.109068515569764
# 2016 Census QuickStats: Warranwood
# Warrawee NSW
# 1.1597463153986385
# 2016 Census QuickStats: Warrawee
# Warriewood NSW
# 1.6342339332376765
# 2016 Census QuickStats: Warriewood
# Warwick WA
# 1.2922048614651391
# 2016 Census QuickStats: Warwick (WA)
# Warwick Farm NSW
# 1.3818289141746918
# 2016 Census QuickStats: Warwick Farm
# Waterfall NSW
# 1.9238071011593123
# 2016 Census QuickStats: Waterfall
# Waterfall Gully SA
# 1.0408868407214489
# 2016 Census QuickStats: Waterfall Gully
# Waterford Qld
# 1.4695362433191583
# 2016 Census QuickStats: Waterford (Qld)
# Waterford WA
# 1.6855572042358213
# 2016 Census QuickStats: Manning - Waterford
# Wrong page
# 1.9191319810699017
# 2016 Census QuickStats: Waterford (WA)
# Waterford West Qld
# 1.175821773145055
# 2016 Census QuickStats: Waterford West
# Waterloo NSW
# 1.93792822474605
# 2016 Census QuickStats: Waterloo (NSW)
# Waterloo Corner SA
# 1.7988696672283133
# 2016 Census QuickStats: Waterloo Corner
# Watermans Bay WA
# 1.8687592542659446
# 2016 Census QuickStats: Watermans Bay
# Waterways Vic
# 1.2018446808042635
# 2016 Census QuickStats: Waterways
# Watson ACT
# 1.825299764340782
# 2016 Census QuickStats: Watson
# Watsonia Vic
# 1.3257165067041021
# 2016 Census QuickStats: Watsonia
# Watsonia North Vic
# 1.3110595745239833
# 2016 Census QuickStats: Watsonia North
# Watsons Bay NSW
# 1.282608183250074
# 2016 Census QuickStats: Watsons Bay
# Watsons Creek Vic
# 1.3765637307176692
# 2016 Census QuickStats: Watsons Creek (Vic.)
# Wattle Glen Vic
# 1.360676324193077
# 2016 Census QuickStats: Wattle Glen
# Wattle Grove NSW
# 1.5912160228381445
# 2016 Census QuickStats: Wattle Grove (NSW)
# Wattle Grove WA
# 1.079882972580866
# 2016 Census QuickStats: Wattle Grove (WA)
# Wattle Park SA
# 1.0498307415305288
# 2016 Census QuickStats: Wattle Park
# Wattleup WA
# 1.420289279986708
# 2016 Census QuickStats: Wattleup
# Wavell Heights Qld
# 1.9779254625828289
# 2016 Census QuickStats: Wavell Heights
# Waverley NSW
# 1.3154757626108793
# 2016 Census QuickStats: Waverley (NSW)
# Waverton NSW
# 1.8606654135063492
# 2016 Census QuickStats: Glen Waverley - West
# Wrong page
# 1.7740014686890437
# 2016 Census QuickStats: Waverton
# Wayville SA
# 1.4102365842755393
# 2016 Census QuickStats: Wayville
# Weddell NT
# 1.2162375269019308
# 2016 Census QuickStats: Weddell
# Wedderburn NSW
# 1.0742752193324177
# 2016 Census QuickStats: Wedderburn (NSW)
# Weetangera ACT
# 1.9545340873189336
# 2016 Census QuickStats: Weetangera
# Welland SA
# 1.8609198228275052
# 2016 Census QuickStats: Welland
# Wellard WA
# 1.0670412760669454
# 2016 Census QuickStats: Wellard
# Wellington Point Qld
# 1.8706041353686653
# 2016 Census QuickStats: Wellington Mill
# Wrong page
# 1.7205050641495858
# 2016 Census QuickStats: Wellington Point
# Welsby Qld
# 1.3721390410931582
# 2016 Census QuickStats: Welsby
# Welshpool WA
# 1.7693503484220032
# 2016 Census QuickStats: Welshpool (WA)
# Wembley WA
# 1.6463087567552144
# 2016 Census QuickStats: Wembley
# Wembley Downs WA
# 1.7993458802463809
# 2016 Census QuickStats: Wembley Downs
# Wentworth Point NSW
# 1.161040599480737
# 2016 Census QuickStats: Wentworth Point
# Wentworthville NSW
# 1.8411083838718536
# 2016 Census QuickStats: Wentworthville
# Werribee Vic
# 1.4700689440870427
# 2016 Census QuickStats: Werribee
# Werribee South Vic
# 1.6106205656471295
# 2016 Census QuickStats: Werribee South
# Werrington NSW
# 1.0402302524964293
# 2016 Census QuickStats: Werrington
# Werrington County NSW
# 1.672544990961405
# 2016 Census QuickStats: Werrington County
# Werrington Downs NSW
# 1.3496658658780691
# 2016 Census QuickStats: Werrington Downs
# Wesburn Vic
# 1.7645245713583186
# 2016 Census QuickStats: Wesburn
# West Beach SA
# 1.180904761067913
# 2016 Census QuickStats: West Beach (SA)
# West Croydon SA
# 1.4222807931093986
# 2016 Census QuickStats: West Croydon
# West End Qld
# 1.2339362496741622
# 2016 Census QuickStats: West End (Brisbane - Qld)
# West Footscray Vic
# 1.6211836256130454
# 2016 Census QuickStats: West Footscray
# West Hindmarsh SA
# 1.1493898338319701
# 2016 Census QuickStats: West Hindmarsh
# West Hobart Tas
# 1.0487602691396924
# 2016 Census QuickStats: West Hobart
# West Hoxton NSW
# 1.398062856364528
# 2016 Census QuickStats: West Hoxton
# West Ipswich Qld
# 1.5704333547979443
# 2016 Census QuickStats: West Ipswich
# West Lakes SA
# 1.7182680902995269
# 2016 Census QuickStats: West Lakes
# West Lakes Shore SA
# 1.4274400050017217
# 2016 Census QuickStats: West Lakes Shore
# West Leederville WA
# 1.905005070488051
# 2016 Census QuickStats: West Leederville
# West Melbourne Vic
# 1.952648225881129
# 2016 Census QuickStats: West Melbourne
# West Moonah Tas
# 1.3225779559577562
# 2016 Census QuickStats: West Moonah
# West Pennant Hills NSW
# 1.7589209068760596
# 2016 Census QuickStats: West Pennant Hills
# West Perth WA
# 1.8065208274752822
# 2016 Census QuickStats: West Perth
# West Pymble NSW
# 1.5224028319698941
# 2016 Census QuickStats: West Pymble
# West Richmond SA
# 1.2126619001391608
# 2016 Census QuickStats: West Richmond
# West Ryde NSW
# 1.752076961140017
# 2016 Census QuickStats: West Ryde
# West Swan WA
# 1.9021445413870324
# 2016 Census QuickStats: West Swan
# Westbourne Park SA
# 1.6775477727936874
# 2016 Census QuickStats: Westbourne Park
# Westlake Qld
# 1.2132086281206949
# 2016 Census QuickStats: Westlake
# Westleigh NSW
# 1.6028037656331553
# 2016 Census QuickStats: Westleigh
# Westmead NSW
# 1.8929867470917163
# 2016 Census QuickStats: Westmead
# Westmeadows Vic
# 1.16623811486336
# 2016 Census QuickStats: Westmeadows
# Westminster WA
# 1.0319776482700291
# 2016 Census QuickStats: Westminster
# Weston ACT
# 1.2268509004793406
# 2016 Census QuickStats: West and North West
# Wrong page
# 1.480378254529243
# 2016 Census QuickStats: Weston (ACT)
# Wetherill Park NSW
# 1.1186272554979577
# 2016 Census QuickStats: Wetherill Park
# Whalan NSW
# 1.494004786225256
# 2016 Census QuickStats: Whalan
# Whale Beach NSW
# 1.6941738645305924
# 2016 Census QuickStats: Whale Beach
# Wheeler Heights NSW
# 1.4910786584249955
# 2016 Census QuickStats: Wheeler Heights
# Wheelers Hill Vic
# 1.046406955229421
# 2016 Census QuickStats: Wheelers Hill
# White Gum Valley WA
# 1.9771424172389234
# 2016 Census QuickStats: White Gum Valley
# White Patch Qld
# 1.3671292725985833
# 2016 Census QuickStats: White Patch
# Whiteman WA
# 1.662653203288229
# 2016 Census QuickStats: Whiteman
# Whites Valley SA
# 1.0562315658186572
# 2016 Census QuickStats: Whites Valley
# Whiteside Qld
# 1.96092232563956
# 2016 Census QuickStats: Whiteside
# Whittlesea Vic
# 1.7650965289243612
# 2016 Census QuickStats: White Patch
# Wrong page
# 1.0210728056094935
# 2016 Census QuickStats: Whittlesea
# Wickham NT
# 1.9054960763203714
# 2016 Census QuickStats: Wickham (NT)
# Wights Mountain Qld
# 1.0533496450169257
# 2016 Census QuickStats: Wights Mountain
# Wilberforce NSW
# 1.7176979908418688
# 2016 Census QuickStats: Wilberforce (NSW)
# Wildwood Vic
# 1.1547781619178805
# 2016 Census QuickStats: Wildwood
# Wiley Park NSW
# 1.7427813068371982
# 2016 Census QuickStats: Wiley Park
# Willagee WA
# 1.5117126073450216
# 2016 Census QuickStats: Willagee
# Willaston SA
# 1.4310051087745044
# 2016 Census QuickStats: Willaston
# Willawong Qld
# 1.1202182241143457
# 2016 Census QuickStats: Willawong
# Willetton WA
# 1.7488388258696093
# 2016 Census QuickStats: Willetton
# Williams Landing Vic
# 1.5457529170571516
# 2016 Census QuickStats: Williams Landing
# Williamstown Vic
# 1.319458168516468
# 2016 Census QuickStats: Williamstown (Vic.)
# Williamstown North Vic
# 1.6178205371039363
# 2016 Census QuickStats: Williamstown North
# Willmot NSW
# 1.177553864699691
# 2016 Census QuickStats: Willawarrin
# Wrong page
# 1.653658786002762
# 2016 Census QuickStats: Willawarrin
# Wrong page
# 1.3419825360123467
# 2016 Census QuickStats: Wild Horse Plains
# Wrong page
# 1.7155486943946228
# 2016 Census QuickStats: Willmot
# Willoughby NSW
# 1.068480101364834
# 2016 Census QuickStats: Willoughby (NSW)
# Willoughby East NSW
# 1.4439391817845975
# 2016 Census QuickStats: Willoughby East
# Willowbank Qld
# 1.7721225409009556
# 2016 Census QuickStats: Willowbank
# Willunga SA
# 1.7942856644389868
# 2016 Census QuickStats: Willunga
# Willunga South SA
# 1.422431628296367
# 2016 Census QuickStats: Willunga South
# Wilson WA
# 1.2379668906420616
# 2016 Census QuickStats: Wilson
# Wilston Qld
# 1.013792329329553
# 2016 Census QuickStats: Wilston
# Windaroo Qld
# 1.0703184513539186
# 2016 Census QuickStats: Windaroo
# Windsor Qld
# 1.7062478497663112
# 2016 Census QuickStats: Windsor (Qld)
# Windsor NSW
# 1.1569308599159904
# 2016 Census QuickStats: Windsor (NSW)
# Windsor Vic
# 1.4305343315179346
# 2016 Census QuickStats: Windsor (Vic.)
# Windsor Downs NSW
# 1.8587200977448588
# 2016 Census QuickStats: Windsor Downs
# Windsor Gardens SA
# 1.5570735293207634
# 2016 Census QuickStats: Windsor Gardens
# Wingfield SA
# 1.2365216948107984
# 2016 Census QuickStats: Wingfield
# Winnellie NT
# 1.2563264270131471
# 2016 Census QuickStats: Winnellie
# Winston Hills NSW
# 1.9286004607276044
# 2016 Census QuickStats: Winston Hills
# Winthrop WA
# 1.726630816164604
# 2016 Census QuickStats: Winthrop
# Wisemans Ferry NSW
# 1.454892770329755
# 2016 Census QuickStats: Wisemans Ferry
# Wishart Qld
# 1.2125518746918211
# 2016 Census QuickStats: Wishart (Qld)
# Wishart NT
# 1.9955942167370786
# 2016 Census QuickStats: Wishart (NT)
# Wishart
# Wolffdene Qld
# 1.9869337835834733
# 2016 Census QuickStats: Wolffdene
# Wollert Vic
# 1.3798956907708537
# 2016 Census QuickStats: Wollert
# Wolli Creek NSW
# 1.7881437325644083
# 2016 Census QuickStats: Wolli Creek
# Wollstonecraft NSW
# 1.1087299526983918
# 2016 Census QuickStats: Wollstonecraft
# Wonga Park Vic
# 1.2705115171888142
# 2016 Census QuickStats: Wonga Park
# Woodbine NSW
# 1.8332835906852556
# 2016 Census QuickStats: Woodbine (NSW)
# Woodbridge WA
# 1.8426463708314402
# 2016 Census QuickStats: Woodbridge (WA)
# Woodcroft NSW
# 1.6207723132443852
# 2016 Census QuickStats: Woodcroft (NSW)
# Woodcroft SA
# 1.2129775742934061
# 2016 Census QuickStats: Woodcroft (SA)
# Woodend Qld
# 1.7484209023241961
# 2016 Census QuickStats: Woodburn (Shoalhaven - NSW)
# Wrong page
# 1.4350954827635702
# 2016 Census QuickStats: Woodend (Qld)
# Woodford Qld
# 1.1275160276131357
# 2016 Census QuickStats: Woodburn (Shoalhaven - NSW)
# Wrong page
# 1.6036872878274626
# 2016 Census QuickStats: Woodford (Qld)
# Woodhill Qld
# 1.1759336778382088
# 2016 Census QuickStats: Woodhill (Qld)
# Woodlands WA
# 1.559699061019834
# 2016 Census QuickStats: Woodlands (WA)
# Woodpark NSW
# 1.6869079044101323
# 2016 Census QuickStats: Woodpark
# Woodridge Qld
# 1.0886594180889966
# 2016 Census QuickStats: Woodridge (Qld)
# Woodroffe NT
# 1.2851865086595455
# 2016 Census QuickStats: Woodburn (Shoalhaven - NSW)
# Wrong page
# 1.2478574245210354
# 2016 Census QuickStats: Woodroffe
# Woodstock Vic
# 1.5218021385345195
# 2016 Census QuickStats: Woodstock (Vic.)
# Woodvale WA
# 1.755490655377931
# 2016 Census QuickStats: Woodvale (WA)
# Woodville SA
# 1.4666066388817791
# 2016 Census QuickStats: Woodville (SA)
# Woodville Gardens SA
# 1.5105684302264735
# 2016 Census QuickStats: Woodville Gardens
# Woodville North SA
# 1.874011923386246
# 2016 Census QuickStats: Woodville North
# Woodville Park SA
# 1.0188481263332054
# 2016 Census QuickStats: Woodville Park
# Woodville South SA
# 1.1754687916744402
# 2016 Census QuickStats: Woodville South
# Woodville West SA
# 1.3055146947536538
# 2016 Census QuickStats: Woodville West
# Woody Point Qld
# 1.3196529726992958
# 2016 Census QuickStats: Woody Point
# Woollahra NSW
# 1.9840089467301938
# 2016 Census QuickStats: Woollahra
# Woolloomooloo NSW
# 1.7672370701543643
# 2016 Census QuickStats: Woolloomooloo
# Woolner NT
# 1.2992054676537426
# 2016 Census QuickStats: Woolner
# Woolooware NSW
# 1.4591273247996162
# 2016 Census QuickStats: Woolooware
# Wooloowin Qld
# 1.0001717421812817
# 2016 Census QuickStats: Wooloowin
# Woolshed Qld
# 1.8442529483478067
# 2016 Census QuickStats: Woolshed
# Woolwich NSW
# 1.7773527340375956
# 2016 Census QuickStats: Woolwich
# Woori Yallock Vic
# 1.3047012893873342
# 2016 Census QuickStats: Woori Yallock
# Woorim Qld
# 1.4293100370331235
# 2016 Census QuickStats: Woorim
# Wooroloo WA
# 1.3346737476923938
# 2016 Census QuickStats: Wooroloo
# Woronora NSW
# 1.6430622118031446
# 2016 Census QuickStats: Woronora
# Woronora Heights NSW
# 1.2794992027626666
# 2016 Census QuickStats: Woronora Heights
# Wright ACT
# 1.3973180631167006
# 2016 Census QuickStats: Wright
# Wulagi NT
# 1.468060257697792
# 2016 Census QuickStats: Wulagi
# Wulkuraka Qld
# 1.6675610523175077
# 2016 Census QuickStats: Wulkuraka
# Wungong WA
# 1.3146846576897913
# 2016 Census QuickStats: Wungong
# Wyndham Vale Vic
# 1.7990128289490954
# 2016 Census QuickStats: Wyndham Vale
# Wynn Vale SA
# 1.4398408528285151
# 2016 Census QuickStats: Wynn Vale
# Wynnum Qld
# 1.9692388995276549
# 2016 Census QuickStats: Wynnum
# Wynnum West Qld
# 1.3441909097297313
# 2016 Census QuickStats: Wynnum West
# Yagoona NSW
# 1.3240824468834653
# 2016 Census QuickStats: Yagoona
# Yallambie Vic
# 1.4100212370236227
# 2016 Census QuickStats: Yallambie
# Yamanto Qld
# 1.493734872219248
# 2016 Census QuickStats: Yamanto
# Yan Yean Vic
# 1.0304097227615214
# 2016 Census QuickStats: Yan Yean
# Yangebup WA
# 1.6968030032751442
# 2016 Census QuickStats: Yangebup
# Yannathan Vic
# 1.2292799356065078
# 2016 Census QuickStats: Yannathan
# Yarra Glen Vic
# 1.469407570247946
# 2016 Census QuickStats: Yarra Glen
# Yarra Junction Vic
# 1.0602042766800324
# 2016 Census QuickStats: Yarra Junction
# Yarrabilba Qld
# 1.7815197502825002
# 2016 Census QuickStats: Yarrabilba
# Yarralumla ACT
# 1.9696009201143374
# 2016 Census QuickStats: Yarralumla
# Yarrambat Vic
# 1.5681220304294086
# 2016 Census QuickStats: Yarrambat
# Yarramundi NSW
# 1.5472655572766525
# 2016 Census QuickStats: Yarramundi
# Yarraville Vic
# 1.7493340893384772
# 2016 Census QuickStats: Yarraville
# Yarrawarrah NSW
# 1.854618327818948
# 2016 Census QuickStats: Yarrawarrah
# Yarrawonga NT
# 1.8340039526455736
# 2016 Census QuickStats: Yarrawonga (NT)
# Yatala Vale SA
# 1.4186024378185866
# 2016 Census QuickStats: Yatala Vale
# Yattalunga SA
# 1.1203065607746652
# 2016 Census QuickStats: Yattalunga (SA)
# Yeerongpilly Qld
# 1.507602578177794
# 2016 Census QuickStats: Yeerongpilly
# Yellingbo Vic
# 1.661781558434274
# 2016 Census QuickStats: Yellingbo
# Yennora NSW
# 1.120009517264025
# 2016 Census QuickStats: Yennora
# Yering Vic
# 1.6342814445230271
# 2016 Census QuickStats: Yering
# Yeronga Qld
# 1.682750879716929
# 2016 Census QuickStats: Yeronga
# Yokine WA
# 1.5870595788251185
# 2016 Census QuickStats: Yokine
# Yowie Bay NSW
# 1.311881461411713
# 2016 Census QuickStats: Yowie Bay
# Yugar Qld
# 1.8477011832103982
# 2016 Census QuickStats: Yugar
# Yuroke Vic
# 1.7665331509789564
# 2016 Census QuickStats: Yuroke
# Zetland NSW
# 1.9365055011170504
# 2016 Census QuickStats: Zetland
# Zillmere Qld
# 1.2826284547983764
# 2016 Census QuickStats: Zillmere
# Zuccoli NT
# 1.3913026481759363
# 2016 Census QuickStats: Zuccoli

# %% [markdown]
# #### Convert dictionary to table

# %%
df = pd.DataFrame(ABS_data).T

df.index.name = 'Suburb'
df.reset_index(inplace=True)

# Move 'State' column to the front
cols = list(df)
cols.insert(1, cols.pop(cols.index('State')))
df = df.loc[:, cols]

# %%
df.head()
# Out:
#            Suburb State  Age_0-4 years_count  Age_0-4 years_percentage  \
# 0      Abbotsbury   NSW                214.0                       5.0
# 1      Abbotsford   NSW                306.0                       5.7
# 2      Abbotsford   Vic                319.0                       3.9
# 3      Aberfeldie   Vic                179.0                       4.6
# 4  Aberfoyle Park    SA                587.0                       5.3
#
#    Age_10-14 years_count  Age_10-14 years_percentage  Age_15-19 years_count  \
# 0                  279.0                         6.6                  347.0
# 1                  239.0                         4.5                  225.0
# 2                  153.0                         1.9                  210.0
# 3                  291.0                         7.5                  348.0
# 4                  677.0                         6.1                  846.0
#
#    Age_15-19 years_percentage  Age_20-24 years_count  \
# 0                         8.2                  377.0
# 1                         4.2                  202.0
# 2                         2.6                  760.0
# 3                         8.9                  284.0
# 4                         7.7                  691.0
#
#    Age_20-24 years_percentage  ...  \
# 0                         8.9  ...
# 1                         3.8  ...
# 2                         9.3  ...
# 3                         7.3  ...
# 4                         6.3  ...
#
#    Unpaid domestic work, number of hours_Less than 5 hours per week_count  \
# 0                                              880.0
# 1                                             1192.0
# 2                                             2688.0
# 3                                              891.0
# 4                                             2205.0
#
#    Unpaid domestic work, number of hours_Less than 5 hours per week_percentage  \
# 0                                               25.1
# 1                                               26.2
# 2                                               35.7
# 3                                               28.1
# 4                                               24.2
#
#    Unpaid work_Cared for child/children (last two weeks)_count  \
# 0                                              884.0
# 1                                             1233.0
# 2                                             1132.0
# 3                                              921.0
# 4                                             2775.0
#
#    Unpaid work_Cared for child/children (last two weeks)_percentage  \
# 0                                               25.2
# 1                                               27.1
# 2                                               15.0
# 3                                               29.0
# 4                                               30.5
#
#    Unpaid work_Did unpaid domestic work (last week)_count  \
# 0                                             2346.0
# 1                                             3267.0
# 2                                             5489.0
# 3                                             2404.0
# 4                                             7181.0
#
#    Unpaid work_Did unpaid domestic work (last week)_percentage  \
# 0                                               67.0
# 1                                               71.8
# 2                                               72.8
# 3                                               75.8
# 4                                               79.0
#
#    Unpaid work_Did voluntary work through an organisation or group (last 12 months)_count  \
# 0                                              439.0
# 1                                              831.0
# 2                                             1506.0
# 3                                              759.0
# 4                                             2151.0
#
#    Unpaid work_Did voluntary work through an organisation or group (last 12 months)_percentage  \
# 0                                               12.5
# 1                                               18.3
# 2                                               20.0
# 3                                               24.0
# 4                                               23.7
#
#    Unpaid work_Provided unpaid assistance to a person with a disability (last two weeks)_count  \
# 0                                              507.0
# 1                                              606.0
# 2                                              563.0
# 3                                              476.0
# 4                                             1167.0
#
#    Unpaid work_Provided unpaid assistance to a person with a disability (last two weeks)_percentage
# 0                                               14.5
# 1                                               13.3
# 2                                                7.5
# 3                                               15.0
# 4                                               12.8
#
# [5 rows x 291 columns]

# %% [markdown]
# #### Clean data

# %%
# Remove characters from columns
for column in df:
    df[column] = df[column].str.replace(',', '')
    df[column] = df[column].str.replace('$', '')
    df[column] = df[column].str.replace('%', '')
    df[column] = df[column].replace('--', np.nan)
        
# Convert string to float
for column in df:
    if ('count' in column) or ('percentage' in column):
        df[column] = pd.to_numeric(df[column])

# %%
# Remove state title from suburb column
df['Suburb'] = df['Suburb'].str.split('_')
df['Suburb'] = df.Suburb.map(lambda x: x[0])

# %%
# Fill median age empty rows
df['Age_Median age_count'] = df.apply(
    lambda row: row['People_Median age_count'] if np.isnan(row['Age_Median age_count'])
                                                           else row['Age_Median age_count'], axis=1
)

df['People_People_count'] = df.apply(
    lambda row: row['People_Male_count'] + row['People_Female_count'] if np.isnan(row['People_People_count'])
                                                           else row['People_People_count'], axis=1
)

# %%
# Drop columns
columns = ['People_Median age_count', 'Age_Median age_percentage', 'Rent weekly payments_Median rent_percentage']
df.drop(columns, inplace=True, axis=1)

# %%
# Rename columns
df.rename({'Age_Median age_count':'Age_Median age',
           'Rent weekly payments_Median rent_count':'Rent weekly payments_Median rent'}, axis=1, inplace=True)

# %% [markdown]
# #### Save dataframe as csv

# %%
df.to_csv('ABS_2016_data.csv')
